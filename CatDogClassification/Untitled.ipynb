# %%
import tensorflow as tf
import keras as k
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def versus(prediction):
    if prediction[0] > 0:
        print(f'Ты СОБАКА на {round(abs(prediction[0][0]) * 100, 2)}%')
    else:
        print(f'Ты котик на {round(abs(prediction[0][0]) * 100, 2)}%')
    plt.imshow(img/255)

# %%
model = k.models.load_model('EfficientNetB0_4_2')

# %%
img = Image.open('C:\\Users\\vikto\\Downloads\\xKt3wC0bgTU.jpg').resize((224, 224), Image.ANTIALIAS)
img = np.array(img)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  Data_augmentation_layer (Se  (None, 224, 224, 3)      0
#  quential)
#
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  Global_Average_Pool_2D (Glo  (None, 1280)             0
#  balAveragePooling2D)
#
#  DropOut_layer (Dropout)     (None, 1280)              0
#
#  Output_layer (Dense)        (None, 1)                 1281
#
# ...
# Total params: 4,050,852
# Trainable params: 4,008,829
# Non-trainable params: 42,023
# _________________________________________________________________

# %%
prediction = model.predict(img[None,:,:])
versus(prediction)
# Out:
# Ты котик на 89.3%
